# %%
import pyspark
from pyspark.sql import SparkSession

# %%
dbutils.fs.mount(

  source = "wasbs://housing@zainsa.blob.core.windows.net",

  mount_point = "/mnt/housing",

  extra_configs = {"fs.azure.account.key.zainsa.blob.core.windows.net":"+qL6FAeyW6/s9mA0+WgxlFyfdcfogsn9993Bx4jD3xFpi++RYUTjmLp0/Glmg0ruJWE4wr7LVeEm+ASthj1OUQ=="})
# Out:
# True

# %%
df=spark.read.csv("/mnt/housing/housing_in_london_monthly_variables.csv")

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# spark.conf.set("fs.azure.account.key.azurestorage.blob.core.windows.net","+qL6FAeyW6/s9mA0+WgxlFyfdcfogsn9993Bx4jD3xFpi++RYUTjmLp0/Glmg0ruJWE4wr7LVeEm+ASthj1OUQ==")

df.write.option("header", "true").format("com.databricks.spark.csv").save("/mnt/housing/out.csv")
